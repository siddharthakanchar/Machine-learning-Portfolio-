# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\siddh'

# %%
os.chdir("C:/Users/siddh/OneDrive/Desktop/Data sets")

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
df1=pd.read_csv("insurance.csv")

# %%
df1
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
df1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df1['region'].value_counts()
# Out:
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df1.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
import seaborn as sns
corr=df1.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
features=df1.iloc[:,:-1].values

# %%
features
# Out:
# array([[19, 'female', 27.9, 0, 'yes', 'southwest'],
#        [18, 'male', 33.77, 1, 'no', 'southeast'],
#        [28, 'male', 33.0, 3, 'no', 'southeast'],
#        ...,
#        [18, 'female', 36.85, 0, 'no', 'southeast'],
#        [21, 'female', 25.8, 0, 'no', 'southwest'],
#        [61, 'female', 29.07, 0, 'yes', 'northwest']], dtype=object)

# %%
labels=df1.iloc[:,-1].values

# %%
labels
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
inps=pd.DataFrame(features)

# %%
inps.columns=['age','sex','bmi','children','smoker','region']

# %%
inps
# Out:
#      age     sex     bmi children smoker     region
# 0     19  female    27.9        0    yes  southwest
# 1     18    male   33.77        1     no  southeast
# 2     28    male      33        3     no  southeast
# 3     33    male  22.705        0     no  northwest
# 4     32    male   28.88        0     no  northwest
# 5     31  female   25.74        0     no  southeast
# 6     46  female   33.44        1     no  southeast
# 7     37  female   27.74        3     no  northwest
# 8     37    male   29.83        2     no  northeast
# 9     60  female   25.84        0     no  northwest
# 10    25    male   26.22        0     no  northeast
# 11    62  female   26.29        0    yes  southeast
# 12    23    male    34.4        0     no  southwest
# 13    56  female   39.82        0     no  southeast
# 14    27    male   42.13        0    yes  southeast
# 15    19    male    24.6        1     no  southwest
# 16    52  female   30.78        1     no  northeast
# ...

# %%
oups=pd.DataFrame(labels)

# %%
oups.columns=['charges']

# %%
oups
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 5      3756.62160
# 6      8240.58960
# 7      7281.50560
# 8      6406.41070
# 9     28923.13692
# 10     2721.32080
# 11    27808.72510
# 12     1826.84300
# 13    11090.71780
# 14    39611.75770
# 15     1837.23700
# 16    10797.33620
# 17     2395.17155
# 18    10602.38500
# 19    36837.46700
# 20    13228.84695
# 21     4149.73600
# 22     1137.01100
# 23    37701.87680
# 24     6203.90175
# 25    14001.13380
# 26    14451.83515
# 27    12268.63225
# 28     2775.19215
# 29    38711.00000
# ...           ...
# 1308  33900.65300
# 1309   6875.96100
# 1310   6940.90985
# 1311   4571.41305
# 1312   4536.25900
# 1313  36397.57600
# 1314  18765.87545
# 1315  11272.33139
# 1316   1731.67700
# 1317   1163.46270
# 1318  19496.71917
# 1319   7201.70085
# 1320   5425.02335
# 1321  28101.33305
# 1322  12981.34570
# 1323  43896.37630
# 1324   4239.89265
# 1325  13143.33665
# ...

# %%
oups.boxplot(column="charges")

# %%
df1.boxplot(column="age")

# %%
df1.boxplot(column="children")

# %%
df1.boxplot(column="bmi")

# %%
sns.distplot(df1['bmi'])

# %%
sns.distplot(df1['age'])

# %%
sns.distplot(df1['children'])

# %%
inps.describe()
# Out:
#          age   sex     bmi  children smoker     region
# count   1338  1338  1338.0      1338   1338       1338
# unique    47     2   548.0         6      2          4
# top       18  male    32.3         0     no  southeast
# freq      69   676    13.0       574   1064        364

# %%
age=df1['age']
sex=df1['sex']
children=df1['children']
smoker=df1['smoker']
region=df1['region']
bmi=df1['bmi']
charges=df1['charges']

# %%
import statsmodels.api as sm
model1=sm.OLS(bmi,charges).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    bmi   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     1726.
# Date:                Thu, 16 May 2019   Prob (F-statistic):          6.10e-243
# Time:                        14:41:24   Log-Likelihood:                -5949.9
# No. Observations:                1338   AIC:                         1.190e+04
# Df Residuals:                    1337   BIC:                         1.191e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# charges        0.0013   3.14e-05     41.546      0.000       0.001       0.001
# ...

# %%
import statsmodels.api as sm
model2=sm.OLS(age,charges).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    age   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     1868.
# Date:                Thu, 16 May 2019   Prob (F-statistic):          3.95e-256
# Time:                        14:41:25   Log-Likelihood:                -6303.3
# No. Observations:                1338   AIC:                         1.261e+04
# Df Residuals:                    1337   BIC:                         1.261e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# charges        0.0018    4.1e-05     43.224      0.000       0.002       0.002
# ...

# %%
import statsmodels.api as sm
model3=sm.OLS(children,charges).fit()

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               children   R-squared:                       0.282
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     524.3
# Date:                Thu, 16 May 2019   Prob (F-statistic):           3.64e-98
# Time:                        14:41:27   Log-Likelihood:                -2329.4
# No. Observations:                1338   AIC:                             4661.
# Df Residuals:                    1337   BIC:                             4666.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# charges     4.811e-05    2.1e-06     22.897      0.000     4.4e-05    5.22e-05
# ...

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # age ,bmi , children

# %%
X=inps[['age','bmi','children']]
y=oups['charges']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#      age     bmi children
# 744   50   26.41        0
# 363   21    26.4        1
# 10    25   26.22        0
# 970   50   28.16        3
# 634   51    39.7        1
# 554   25  41.325        0
# 314   27    31.4        0
# 419   63   26.98        0
# 525   18   33.88        0
# 1041  18  23.085        0
# 649   58  32.965        0
# 1306  29   21.85        0
# 790   39    41.8        0
# 1044  55  35.245        1
# 104   34    27.5        1
# 1295  20      22        1
# 370   61   21.09        0
# 495   20   27.93        0
# 1162  30   38.83        1
# 903   49   36.85        0
# 125   26  28.785        0
# 694   27    34.8        1
# 979   36   29.92        0
# 1223  20   24.42        0
# 1251  19    19.8        0
# 529   18   25.46        0
# 1018  54  35.815        3
# 1139  19   32.49        0
# 1011  43   20.13        2
# 1097  22   33.77        0
# ...   ..     ...      ...
# 1031  55    35.2        0
# 141   26   32.49        1
# 1110  54    32.3        1
# ...

# %%
y_train
# Out:
# 744      8827.20990
# 363      2597.77900
# 10       2721.32080
# 970     10702.64240
# 634      9391.34600
# 554     17878.90068
# 314     34838.87300
# 419     28950.46920
# 525     11482.63485
# 1041     1704.70015
# 649     12430.95335
# 1306    16115.30450
# 790      5662.22500
# 1044    11394.06555
# 104      5003.85300
# 1295     1964.78000
# 370     13415.03810
# 495      1967.02270
# 1162    18963.17192
# 903      8125.78450
# 125      3385.39915
# 694      3577.99900
# 979      4889.03680
# 1223    26125.67477
# 1251     1241.56500
# 529      1708.00140
# 1018    12495.29085
# 1139    36898.73308
# 1011    18767.73770
# 1097     1674.63230
#            ...
# 1031    44423.80300
# 141      3490.54910
# 1110    11512.40500
# 753     11833.78230
# 1001    34472.84100
# 1239     3238.43570
# 580     12913.99240
# 562      2494.02200
# 398     14988.43200
# 668     45710.20785
# 252     44260.74990
# 907      7633.72060
# 468     23288.92840
# 914      5257.50795
# ...

# %%
X_train=X_train.values.reshape((936,3))

# %%
X_train
# Out:
# array([[50, 26.41, 0],
#        [21, 26.4, 1],
#        [25, 26.22, 0],
#        ...,
#        [51, 34.96, 2],
#        [40, 22.22, 2],
#        [57, 27.94, 1]], dtype=object)

# %%
from sklearn import linear_model as lm
model1=lm.LinearRegression()
results=model1.fit(X_train,y_train)

# %%
accuracy=model1.score(X_train,y_train)

# %%
print("accuracy of model is",accuracy)
# Out:
# accuracy of model is 0.11770834190185464

# %%
X_test.describe()
# Out:
#         age     bmi  children
# count   402  402.00       402
# unique   47  288.00         6
# top      19   27.36         0
# freq     26    6.00       175

# %%
X_test=X_test.values.reshape((402,3))

# %%
predictions=model1.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
X_train=X_train.reshape(936,3)
y_train_prediction=model1.predict(X_train)

# %%
X_test=X_test.reshape(402,3)
y_test_prediction=model1.predict(X_test)

# %%
y_test_prediction=model1.predict(X_test)

# %%
X_train
# Out:
# array([[50, 26.41, 0],
#        [21, 26.4, 1],
#        [25, 26.22, 0],
#        ...,
#        [51, 34.96, 2],
#        [40, 22.22, 2],
#        [57, 27.94, 1]], dtype=object)

# %%
y_train_prediction
# Out:
# array([14310.30119248,  7488.93670364,  8121.45538548, 15746.38183659,
#        19156.71583   , 13022.21920172, 10292.26413962, 17681.38018525,
#         8891.09901416,  5388.69945135, 18397.75206756,  7683.97650096,
#        16607.56381972, 18691.65899617, 11031.97232155,  5816.28422943,
#        15280.21444273,  7450.81864055, 13727.59858515, 17452.43422194,
#         9198.74860099, 11684.81522373, 12017.87572758,  6312.01155713,
#         4567.98086116,  6159.25979981, 19210.37166378,  8685.20647044,
#        11136.0273569 ,  9835.76205995, 10559.27767135, 14910.94098812,
#        15975.01538529, 15318.39538611, 20637.76321867, 12698.16561911,
#        22167.65924939, 14830.38296497, 16979.92102638, 10810.93488704,
#        12307.30883916,  9850.87719814, 11316.96136869, 16974.53048957,
#        14350.17244785,  9562.75368624, 14827.42138037, 13104.3487445 ,
#        16228.03313137, 13102.75626478,  9788.94949022,  8070.24946401,
# ...

# %%
X_test
# Out:
# array([[19, 35.53, 0],
#        [57, 31.54, 0],
#        [51, 37.0, 0],
#        ...,
#        [20, 28.785, 0],
#        [26, 27.06, 0],
#        [49, 27.1, 1]], dtype=object)

# %%
import numpy as np
rmse_training=(np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training=r2_score(y_train,y_train_prediction)

# %%
print("The model performance for training set")
print("--------------------------------------")
print('RMSE IS []'),format(rmse_training)
print('R2 score is []'),format(r2_training)
# Out:
# The model performance for training set
# --------------------------------------
# RMSE IS []
# R2 score is []
# (None, '0.11770834190185464')

# %%
rmse_testing=(np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing=r2_score(y_test,y_test_prediction)
print("The model performance for testing set")
print("-------------------------------------")
print('Root mean squared error:'),format('rmse_testing')
print('R2_score:'),format ('r2_training')
# Out:
# The model performance for testing set
# -------------------------------------
# Root mean squared error:
# R2_score:
# (None, 'r2_training')

# %%
X=X.values.reshape(1338,3)
y_predicted=model1.predict(X)

# %%
plt.plot(X,y_predicted,color='r')
plt.show()

# %% [markdown]
# # age

# %%
X=inps[['age']]
y=oups['charges']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#      age
# 744   50
# 363   21
# 10    25
# 970   50
# 634   51
# 554   25
# 314   27
# 419   63
# 525   18
# 1041  18
# 649   58
# 1306  29
# 790   39
# 1044  55
# 104   34
# 1295  20
# 370   61
# 495   20
# 1162  30
# 903   49
# 125   26
# 694   27
# 979   36
# 1223  20
# 1251  19
# 529   18
# 1018  54
# 1139  19
# 1011  43
# 1097  22
# ...   ..
# 1031  55
# 141   26
# 1110  54
# 753   58
# 1001  24
# 1239  25
# 580   59
# 562   27
# 398   64
# 668   62
# 252   54
# 907   44
# 468   28
# 914   33
# 357   47
# 1278  39
# 1300  45
# 1202  22
# 1305  24
# 508   24
# 749   28
# 129   38
# 144   30
# 960   19
# 847   23
# 715   60
# 905   26
# 1096  51
# 235   40
# 1061  57
#
# [936 rows x 1 columns]

# %%
y_train
# Out:
# 744      8827.20990
# 363      2597.77900
# 10       2721.32080
# 970     10702.64240
# 634      9391.34600
# 554     17878.90068
# 314     34838.87300
# 419     28950.46920
# 525     11482.63485
# 1041     1704.70015
# 649     12430.95335
# 1306    16115.30450
# 790      5662.22500
# 1044    11394.06555
# 104      5003.85300
# 1295     1964.78000
# 370     13415.03810
# 495      1967.02270
# 1162    18963.17192
# 903      8125.78450
# 125      3385.39915
# 694      3577.99900
# 979      4889.03680
# 1223    26125.67477
# 1251     1241.56500
# 529      1708.00140
# 1018    12495.29085
# 1139    36898.73308
# 1011    18767.73770
# 1097     1674.63230
#            ...
# 1031    44423.80300
# 141      3490.54910
# 1110    11512.40500
# 753     11833.78230
# 1001    34472.84100
# 1239     3238.43570
# 580     12913.99240
# 562      2494.02200
# 398     14988.43200
# 668     45710.20785
# 252     44260.74990
# 907      7633.72060
# 468     23288.92840
# 914      5257.50795
# ...

# %%
X_train=X_train.values.reshape((936,1))

# %%
X_train
# Out:
# array([[50],
#        [21],
#        [25],
#        [50],
#        [51],
#        [25],
#        [27],
#        [63],
#        [18],
#        [18],
#        [58],
#        [29],
#        [39],
#        [55],
#        [34],
#        [20],
#        [61],
#        [20],
#        [30],
#        [49],
#        [26],
#        [27],
#        [36],
#        [20],
#        [19],
#        [18],
#        [54],
#        [19],
#        [43],
#        [22],
#        [22],
#        [48],
#        [42],
#        [47],
#        [63],
#        [28],
#        [64],
#        [45],
#        [58],
#        [36],
#        [36],
#        [28],
#        [30],
#        [54],
#        [52],
#        [38],
#        [42],
#        [40],
#        [22],
#        [33],
#        [31],
#        [18],
#        [59],
#        [19],
#        [55],
#        [23],
#        [19],
#        [19],
#        [19],
#        [18],
#        [20],
#        [53],
#        [37],
#        [35],
#        [31],
#        [25],
# ...

# %%
from sklearn import linear_model as lm
model2=lm.LinearRegression()
results=model2.fit(X_train,y_train)

# %%
accuracy=model2.score(X_train,y_train)

# %%
print("accuracy of model is",accuracy)
# Out:
# accuracy of model is 0.0910963973805714

# %%
X_test.describe()
# Out:
#         age
# count   402
# unique   47
# top      19
# freq     26

# %%
X_test=X_test.values.reshape((402,1))

# %%
predictions=model2.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %% [markdown]
# # bmi and charges

# %%
X=inps[['bmi']]
y=oups['charges']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#          bmi
# 744    26.41
# 363     26.4
# 10     26.22
# 970    28.16
# 634     39.7
# 554   41.325
# 314     31.4
# 419    26.98
# 525    33.88
# 1041  23.085
# 649   32.965
# 1306   21.85
# 790     41.8
# 1044  35.245
# 104     27.5
# 1295      22
# 370    21.09
# 495    27.93
# 1162   38.83
# 903    36.85
# 125   28.785
# 694     34.8
# 979    29.92
# 1223   24.42
# 1251    19.8
# 529    25.46
# 1018  35.815
# 1139   32.49
# 1011   20.13
# 1097   33.77
# ...      ...
# 1031    35.2
# 141    32.49
# 1110    32.3
# 753    22.77
# 1001    32.7
# 1239   42.13
# 580    25.46
# 562     30.5
# 398     25.6
# 668   32.015
# 252    34.21
# 907    32.34
# 468    24.32
# 914   24.605
# 357    29.83
# 1278  29.925
# 1300   30.36
# 1202   32.11
# 1305   27.72
# 508    25.27
# 749   30.875
# 129     34.7
# 144    28.69
# 960   39.615
# 847    50.38
# 715     28.9
# 905   29.355
# 1096   34.96
# 235    22.22
# 1061   27.94
#
# [936 rows x 1 columns]

# %%
y_train
# Out:
# 744      8827.20990
# 363      2597.77900
# 10       2721.32080
# 970     10702.64240
# 634      9391.34600
# 554     17878.90068
# 314     34838.87300
# 419     28950.46920
# 525     11482.63485
# 1041     1704.70015
# 649     12430.95335
# 1306    16115.30450
# 790      5662.22500
# 1044    11394.06555
# 104      5003.85300
# 1295     1964.78000
# 370     13415.03810
# 495      1967.02270
# 1162    18963.17192
# 903      8125.78450
# 125      3385.39915
# 694      3577.99900
# 979      4889.03680
# 1223    26125.67477
# 1251     1241.56500
# 529      1708.00140
# 1018    12495.29085
# 1139    36898.73308
# 1011    18767.73770
# 1097     1674.63230
#            ...
# 1031    44423.80300
# 141      3490.54910
# 1110    11512.40500
# 753     11833.78230
# 1001    34472.84100
# 1239     3238.43570
# 580     12913.99240
# 562      2494.02200
# 398     14988.43200
# 668     45710.20785
# 252     44260.74990
# 907      7633.72060
# 468     23288.92840
# 914      5257.50795
# ...

# %%
X_train=X_train.values.reshape((936,1))

# %%
X_train
# Out:
# array([[26.41],
#        [26.4],
#        [26.22],
#        [28.16],
#        [39.7],
#        [41.325],
#        [31.4],
#        [26.98],
#        [33.88],
#        [23.085],
#        [32.965],
#        [21.85],
#        [41.8],
#        [35.245],
#        [27.5],
#        [22.0],
#        [21.09],
#        [27.93],
#        [38.83],
#        [36.85],
#        [28.785],
#        [34.8],
#        [29.92],
#        [24.42],
#        [19.8],
#        [25.46],
#        [35.815],
#        [32.49],
#        [20.13],
#        [33.77],
#        [36.0],
#        [28.88],
#        [35.8],
#        [28.215],
#        [35.2],
#        [38.06],
#        [39.16],
#        [31.79],
#        [28.595],
#        [26.2],
#        [29.92],
#        [27.5],
#        [31.4],
#        [31.6],
#        [24.13],
#        [19.95],
#        [33.155],
#        [29.355],
#        [52.58],
#        [35.53],
#        [25.935],
#        [31.35],
#        [27.5],
#        [44.88],
#        [26.8],
# ...

# %%
from sklearn import linear_model as lm
model3=lm.LinearRegression()
results=model3.fit(X_train,y_train)

# %%
accuracy=model3.score(X_train,y_train)

# %%
print("accuracy of model is",accuracy)
# Out:
# accuracy of model is 0.03825877603222383

# %%
X_test.describe()
# Out:
#            bmi
# count   402.00
# unique  288.00
# top      27.36
# freq      6.00

# %%
X_test=X_test.values.reshape((402,1))

# %%
predictions=model3.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
X=inps[['bmi','age']]
y=oups['charges']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#          bmi age
# 744    26.41  50
# 363     26.4  21
# 10     26.22  25
# 970    28.16  50
# 634     39.7  51
# 554   41.325  25
# 314     31.4  27
# 419    26.98  63
# 525    33.88  18
# 1041  23.085  18
# 649   32.965  58
# 1306   21.85  29
# 790     41.8  39
# 1044  35.245  55
# 104     27.5  34
# 1295      22  20
# 370    21.09  61
# 495    27.93  20
# 1162   38.83  30
# 903    36.85  49
# 125   28.785  26
# 694     34.8  27
# 979    29.92  36
# 1223   24.42  20
# 1251    19.8  19
# 529    25.46  18
# 1018  35.815  54
# 1139   32.49  19
# 1011   20.13  43
# 1097   33.77  22
# ...      ...  ..
# 1031    35.2  55
# 141    32.49  26
# 1110    32.3  54
# 753    22.77  58
# 1001    32.7  24
# 1239   42.13  25
# 580    25.46  59
# 562     30.5  27
# 398     25.6  64
# 668   32.015  62
# 252    34.21  54
# 907    32.34  44
# 468    24.32  28
# 914   24.605  33
# 357    29.83  47
# 1278  29.925  39
# 1300   30.36  45
# 1202   32.11  22
# 1305   27.72  24
# 508    25.27  24
# ...

# %%
y_train
# Out:
# 744      8827.20990
# 363      2597.77900
# 10       2721.32080
# 970     10702.64240
# 634      9391.34600
# 554     17878.90068
# 314     34838.87300
# 419     28950.46920
# 525     11482.63485
# 1041     1704.70015
# 649     12430.95335
# 1306    16115.30450
# 790      5662.22500
# 1044    11394.06555
# 104      5003.85300
# 1295     1964.78000
# 370     13415.03810
# 495      1967.02270
# 1162    18963.17192
# 903      8125.78450
# 125      3385.39915
# 694      3577.99900
# 979      4889.03680
# 1223    26125.67477
# 1251     1241.56500
# 529      1708.00140
# 1018    12495.29085
# 1139    36898.73308
# 1011    18767.73770
# 1097     1674.63230
#            ...
# 1031    44423.80300
# 141      3490.54910
# 1110    11512.40500
# 753     11833.78230
# 1001    34472.84100
# 1239     3238.43570
# 580     12913.99240
# 562      2494.02200
# 398     14988.43200
# 668     45710.20785
# 252     44260.74990
# 907      7633.72060
# 468     23288.92840
# 914      5257.50795
# ...

# %%
X_train=X_train.values.reshape((936,2))

# %%
X_train
# Out:
# array([[26.41, 50],
#        [26.4, 21],
#        [26.22, 25],
#        ...,
#        [34.96, 51],
#        [22.22, 40],
#        [27.94, 57]], dtype=object)

# %%
from sklearn import linear_model as lm
model4=lm.LinearRegression()
results=model4.fit(X_train,y_train)

# %%
accuracy=model4.score(X_train,y_train)

# %%
print("accuracy of model is",accuracy)
# Out:
# accuracy of model is 0.11686688760314767

# %%
X_test.describe()
# Out:
#            bmi  age
# count   402.00  402
# unique  288.00   47
# top      27.36   19
# freq      6.00   26

# %%
X_test=X_test.values.reshape((402,2))

# %%
predictions=model4.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
X=inps[['bmi','children']]
y=oups['charges']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#          bmi children
# 744    26.41        0
# 363     26.4        1
# 10     26.22        0
# 970    28.16        3
# 634     39.7        1
# 554   41.325        0
# 314     31.4        0
# 419    26.98        0
# 525    33.88        0
# 1041  23.085        0
# 649   32.965        0
# 1306   21.85        0
# 790     41.8        0
# 1044  35.245        1
# 104     27.5        1
# 1295      22        1
# 370    21.09        0
# 495    27.93        0
# 1162   38.83        1
# 903    36.85        0
# 125   28.785        0
# 694     34.8        1
# 979    29.92        0
# 1223   24.42        0
# 1251    19.8        0
# 529    25.46        0
# 1018  35.815        3
# 1139   32.49        0
# 1011   20.13        2
# 1097   33.77        0
# ...      ...      ...
# 1031    35.2        0
# 141    32.49        1
# 1110    32.3        1
# 753    22.77        0
# 1001    32.7        0
# 1239   42.13        1
# 580    25.46        1
# 562     30.5        0
# 398     25.6        2
# ...

# %%
y_train
# Out:
# 744      8827.20990
# 363      2597.77900
# 10       2721.32080
# 970     10702.64240
# 634      9391.34600
# 554     17878.90068
# 314     34838.87300
# 419     28950.46920
# 525     11482.63485
# 1041     1704.70015
# 649     12430.95335
# 1306    16115.30450
# 790      5662.22500
# 1044    11394.06555
# 104      5003.85300
# 1295     1964.78000
# 370     13415.03810
# 495      1967.02270
# 1162    18963.17192
# 903      8125.78450
# 125      3385.39915
# 694      3577.99900
# 979      4889.03680
# 1223    26125.67477
# 1251     1241.56500
# 529      1708.00140
# 1018    12495.29085
# 1139    36898.73308
# 1011    18767.73770
# 1097     1674.63230
#            ...
# 1031    44423.80300
# 141      3490.54910
# 1110    11512.40500
# 753     11833.78230
# 1001    34472.84100
# 1239     3238.43570
# 580     12913.99240
# 562      2494.02200
# 398     14988.43200
# 668     45710.20785
# 252     44260.74990
# 907      7633.72060
# 468     23288.92840
# 914      5257.50795
# ...

# %%
X_train=X_train.values.reshape((936,2))

# %%
X_train
# Out:
# array([[26.41, 0],
#        [26.4, 1],
#        [26.22, 0],
#        ...,
#        [34.96, 2],
#        [22.22, 2],
#        [27.94, 1]], dtype=object)

# %%
from sklearn import linear_model as lm
model5=lm.LinearRegression()
results=model5.fit(X_train,y_train)

# %%
accuracy=model5.score(X_train,y_train)

# %%
print("accuracy of model is",accuracy)
# Out:
# accuracy of model is 0.039412801270089615

# %%
X_test.describe()
# Out:
#            bmi  children
# count   402.00       402
# unique  288.00         6
# top      27.36         0
# freq      6.00       175

# %%
X_test=X_test.reshape((402,2))

# %%
predictions=model5.predict(X_test)

# %%
plt.scatter(y_test,predictions)
