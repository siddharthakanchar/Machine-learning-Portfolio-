# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\siddh'

# %%
os.chdir("C:/Users/siddh/OneDrive/Desktop/Data sets")

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
df1=pd.read_csv("dataset.csv")

# %%
df1
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000001  P00069042      F   0-17          10             A
# 1   1000001  P00248942      F   0-17          10             A
# 2   1000001  P00087842      F   0-17          10             A
# 3   1000001  P00085442      F   0-17          10             A
# 4   1000002  P00285442      M    55+          16             C
# 5   1000003  P00193542      M  26-35          15             A
# 6   1000004  P00184942      M  46-50           7             B
# 7   1000004  P00346142      M  46-50           7             B
# 8   1000004   P0097242      M  46-50           7             B
# 9   1000005  P00274942      M  26-35          20             A
# 10  1000005  P00251242      M  26-35          20             A
# 11  1000005  P00014542      M  26-35          20             A
# 12  1000005  P00031342      M  26-35          20             A
# 13  1000005  P00145042      M  26-35          20             A
# ...

# %%
df1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# User_ID                        0
# Product_ID                     0
# Gender                         0
# Age                            0
# Occupation                     0
# City_Category                  0
# Stay_In_Current_City_Years     0
# Marital_Status                 0
# Product_Category_1             0
# Product_Category_2            23
# Product_Category_3            61
# Purchase                       0
# dtype: int64

# %%
df1['Product_Category_2'].mean()
# Out:
# 8.447368421052632

# %%
df1['Product_Category_2'].fillna('8.447368421052632',inplace=True)

# %%
df1['Product_Category_3'].mean()
# Out:
# 11.5

# %%
df1['Product_Category_3'].fillna('11.5',inplace=True)

# %%
df1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df1.corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.286025       -0.459982           -0.145279
# Occupation         -0.286025    1.000000       -0.164440            0.149345
# Marital_Status     -0.459982   -0.164440        1.000000           -0.027610
# Product_Category_1 -0.145279    0.149345       -0.027610            1.000000
# Purchase           -0.004351   -0.183602        0.160606           -0.696186
#
#                     Purchase
# User_ID            -0.004351
# Occupation         -0.183602
# Marital_Status      0.160606
# Product_Category_1 -0.696186
# Purchase            1.000000

# %%
import seaborn as sns
corr=df1.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
df1.boxplot(column="Occupation")

# %%
df1.boxplot(column='Product_Category_1')

# %%
df1.boxplot(column='Purchase')

# %%
df1.describe()
# Out:
#             User_ID  Occupation  Marital_Status  Product_Category_1  \
# count  9.900000e+01   99.000000       99.000000           99.000000
# mean   1.000012e+06    6.858586        0.383838            4.323232
# std    5.511686e+00    5.792342        0.488794            3.238254
# min    1.000001e+06    0.000000        0.000000            1.000000
# 25%    1.000008e+06    1.000000        0.000000            1.000000
# 50%    1.000011e+06    7.000000        0.000000            5.000000
# 75%    1.000018e+06   10.000000        1.000000            7.000000
# max    1.000022e+06   20.000000        1.000000           14.000000
#
#            Purchase
# count     99.000000
# mean   10087.848485
# std     5206.701103
# min      697.000000
# 25%     5899.500000
# 50%     8773.000000
# 75%    15191.000000
# max    19672.000000

# %%
df1.corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.286025       -0.459982           -0.145279
# Occupation         -0.286025    1.000000       -0.164440            0.149345
# Marital_Status     -0.459982   -0.164440        1.000000           -0.027610
# Product_Category_1 -0.145279    0.149345       -0.027610            1.000000
# Purchase           -0.004351   -0.183602        0.160606           -0.696186
#
#                     Purchase
# User_ID            -0.004351
# Occupation         -0.183602
# Marital_Status      0.160606
# Product_Category_1 -0.696186
# Purchase            1.000000

# %%
sns.distplot(df1['Occupation'])

# %%
sns.distplot(df1['Product_Category_1'])

# %%
sns.distplot(df1['Purchase'])

# %%
df1=df1.drop(['User_ID','Product_ID'],axis=1)

# %%
df1
# Out:
#    Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0       F   0-17          10             A                          2
# 1       F   0-17          10             A                          2
# 2       F   0-17          10             A                          2
# 3       F   0-17          10             A                          2
# 4       M    55+          16             C                         4+
# 5       M  26-35          15             A                          3
# 6       M  46-50           7             B                          2
# 7       M  46-50           7             B                          2
# 8       M  46-50           7             B                          2
# 9       M  26-35          20             A                          1
# 10      M  26-35          20             A                          1
# 11      M  26-35          20             A                          1
# ...

# %%
df1.Gender.value_counts()
# Out:
# M    53
# F    46
# Name: Gender, dtype: int64

# %%
features=df1.iloc[:,:-1].values

# %%
features
# Out:
# array([['F', '0-17', 10, 'A', '2', 0, 3, '8.447368421052632', '11.5'],
#        ['F', '0-17', 10, 'A', '2', 0, 1, 6.0, 14.0],
#        ['F', '0-17', 10, 'A', '2', 0, 12, '8.447368421052632', '11.5'],
#        ['F', '0-17', 10, 'A', '2', 0, 12, 14.0, '11.5'],
#        ['M', '55+', 16, 'C', '4+', 0, 8, '8.447368421052632', '11.5'],
#        ['M', '26-35', 15, 'A', '3', 0, 1, 2.0, '11.5'],
#        ['M', '46-50', 7, 'B', '2', 1, 1, 8.0, 17.0],
#        ['M', '46-50', 7, 'B', '2', 1, 1, 15.0, '11.5'],
#        ['M', '46-50', 7, 'B', '2', 1, 1, 16.0, '11.5'],
#        ['M', '26-35', 20, 'A', '1', 1, 8, '8.447368421052632', '11.5'],
#        ['M', '26-35', 20, 'A', '1', 1, 5, 11.0, '11.5'],
#        ['M', '26-35', 20, 'A', '1', 1, 8, '8.447368421052632', '11.5'],
#        ['M', '26-35', 20, 'A', '1', 1, 8, '8.447368421052632', '11.5'],
#        ['M', '26-35', 20, 'A', '1', 1, 1, 2.0, 5.0],
#        ['F', '51-55', 9, 'A', '1', 0, 5, 8.0, 14.0],
# ...

# %%
labels=df1.iloc[:,-1].values

# %%
labels
# Out:
# array([ 8370, 15200,  1422,  1057,  7969, 15227, 19215, 15854, 15686,
#         7871,  5254,  3957,  6073, 15665,  5378,  2079, 13055,  8851,
#        11788, 19614,  8584,  9872,  9743,  5982, 11927, 16662,  5887,
#         6973,  5391, 16352,  8886,  5875,  8854, 10946,  5152,  7089,
#        12909,  8770, 15212, 15705,  7947, 18963,  8718, 16406, 12642,
#        10007, 11562,  6171, 19327,  8027, 15246,  6865,  5839, 15912,
#        12107,  5848, 19653,  5958, 11415,  5380,  3594,  4209,  5407,
#         7803, 11458, 11755,  8702, 15872,  8609, 15172,  1780, 10754,
#         2802, 19473, 19672, 19313, 15182, 15985, 16454, 13551,   697,
#         7030,  5430,  8011,  5912,  7746, 19525, 11959, 19172,  8773,
#        11023,  4654,  4664,  8290,  7011,  4211,  1539,  3055, 12099],
#       dtype=int64)

# %%
inps=pd.DataFrame(features)

# %%
inps.columns=['Gender','Age','Occupation','City_category','Stay_In_Current_City_Years','Martial_Status','Product_Category_1','Product_Category_2','Product_Category_3']

# %%
inps
# Out:
#    Gender    Age Occupation City_category Stay_In_Current_City_Years  \
# 0       F   0-17         10             A                          2
# 1       F   0-17         10             A                          2
# 2       F   0-17         10             A                          2
# 3       F   0-17         10             A                          2
# 4       M    55+         16             C                         4+
# 5       M  26-35         15             A                          3
# 6       M  46-50          7             B                          2
# 7       M  46-50          7             B                          2
# 8       M  46-50          7             B                          2
# 9       M  26-35         20             A                          1
# 10      M  26-35         20             A                          1
# 11      M  26-35         20             A                          1
# 12      M  26-35         20             A                          1
# ...

# %%
oups=pd.DataFrame(labels)

# %%
oups.columns=['Purchase']

# %%
oups
# Out:
#     Purchase
# 0       8370
# 1      15200
# 2       1422
# 3       1057
# 4       7969
# 5      15227
# 6      19215
# 7      15854
# 8      15686
# 9       7871
# 10      5254
# 11      3957
# 12      6073
# 13     15665
# 14      5378
# 15      2079
# 16     13055
# 17      8851
# 18     11788
# 19     19614
# 20      8584
# 21      9872
# 22      9743
# 23      5982
# 24     11927
# 25     16662
# 26      5887
# 27      6973
# 28      5391
# 29     16352
# ..       ...
# 69     15172
# 70      1780
# 71     10754
# 72      2802
# 73     19473
# 74     19672
# 75     19313
# 76     15182
# 77     15985
# 78     16454
# 79     13551
# 80       697
# 81      7030
# 82      5430
# 83      8011
# 84      5912
# 85      7746
# 86     19525
# 87     11959
# 88     19172
# 89      8773
# 90     11023
# 91      4654
# 92      4664
# 93      8290
# 94      7011
# 95      4211
# 96      1539
# 97      3055
# 98     12099
#
# [99 rows x 1 columns]

# %%
Gender=df1['Gender']
Age=df1['Age']
Occupation=df1['Occupation']
City_category=df1['City_Category']
Stay_In_Current_City_Years=df1['Stay_In_Current_City_Years']
Marital_Status=df1['Marital_Status']
Product_Category_1=df1['Product_Category_1']
Product_Category_2=df1['Product_Category_2']
Product_Category_3=df1['Product_Category_3']
Purchase=oups['Purchase']

# %%
import statsmodels.api as sm
model1=sm.OLS(Occupation,Purchase).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Occupation   R-squared:                       0.393
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     63.52
# Date:                Thu, 16 May 2019   Prob (F-statistic):           2.94e-12
# Time:                        22:08:42   Log-Likelihood:                -332.81
# No. Observations:                  99   AIC:                             667.6
# Df Residuals:                      98   BIC:                             670.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Purchase       0.0005   6.22e-05      7.970      0.000       0.000       0.001
# ...

# %%
import statsmodels.api as sm
model2=sm.OLS(Product_Category_1,Purchase).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Product_Category_1   R-squared:                       0.274
# Model:                            OLS   Adj. R-squared:                  0.266
# Method:                 Least Squares   F-statistic:                     36.95
# Date:                Thu, 16 May 2019   Prob (F-statistic):           2.33e-08
# Time:                        22:08:42   Log-Likelihood:                -291.44
# No. Observations:                  99   AIC:                             584.9
# Df Residuals:                      98   BIC:                             587.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Purchase       0.0002   4.09e-05      6.078      0.000       0.000       0.000
# ...

# %% [markdown]
# # Model 1-  Occupation

# %%
from sklearn.model_selection import train_test_split

# %%
X=inps[['Occupation']]
y=oups['Purchase']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#    Occupation
# 36          1
# 52          1
# 74          3
# 70          3
# 39          1
# 46          1
# 66          0
# 23         12
# 34          1
# 85         10
# 96         10
# 67          1
# 15          9
# 82          3
# 41          1
# 90         10
# 26         17
# 97         16
# 43          1
# 53          1
# 24         12
# 4          16
# 56          7
# 49          1
# 21         12
# 86         10
# 3          10
# 73          3
# 30          1
# 65          0
# ..        ...
# 57          7
# 22         12
# 61          7
# 63          7
# 7           7
# 95         10
# 13         20
# 68          1
# 84          3
# 14          9
# 29          1
# 28         17
# 11         20
# 18          1
# 20         12
# 50         12
# 25         17
# 6           7
# 71          3
# 76          3
# 1          10
# 16          9
# 64          7
# 79          3
# 5          15
# 75          3
# 9          20
# 72          3
# 12         20
# 37          1
#
# ...

# %%
y_train
# Out:
# 36    12909
# 52     5839
# 74    19672
# 70     1780
# 39    15705
# 46    11562
# 66     8702
# 23     5982
# 34     5152
# 85     7746
# 96     1539
# 67    15872
# 15     2079
# 82     5430
# 41    18963
# 90    11023
# 26     5887
# 97     3055
# 43    16406
# 53    15912
# 24    11927
# 4      7969
# 56    19653
# 49     8027
# 21     9872
# 86    19525
# 3      1057
# 73    19473
# 30     8886
# 65    11755
#       ...
# 57     5958
# 22     9743
# 61     4209
# 63     7803
# 7     15854
# 95     4211
# 13    15665
# 68     8609
# 84     5912
# 14     5378
# 29    16352
# 28     5391
# 11     3957
# 18    11788
# 20     8584
# 50    15246
# 25    16662
# 6     19215
# 71    10754
# 76    15182
# 1     15200
# 16    13055
# 64    11458
# 79    13551
# 5     15227
# 75    19313
# 9      7871
# 72     2802
# 12     6073
# 37     8770
# Name: Purchase, Length: 69, dtype: int64

# %%
X_train=X_train.values.reshape((69,1))

# %%
X_train
# Out:
# array([[1],
#        [1],
#        [3],
#        [3],
#        [1],
#        [1],
#        [0],
#        [12],
#        [1],
#        [10],
#        [10],
#        [1],
#        [9],
#        [3],
#        [1],
#        [10],
#        [17],
#        [16],
#        [1],
#        [1],
#        [12],
#        [16],
#        [7],
#        [1],
#        [12],
#        [10],
#        [10],
#        [3],
#        [1],
#        [0],
#        [1],
#        [1],
#        [1],
#        [12],
#        [10],
#        [7],
#        [7],
#        [10],
#        [10],
#        [7],
#        [12],
#        [7],
#        [7],
#        [7],
#        [10],
#        [20],
#        [1],
#        [3],
#        [9],
#        [1],
#        [17],
#        [20],
#        [1],
#        [12],
#        [12],
#        [17],
#        [7],
#        [3],
#        [3],
#        [10],
#        [9],
#        [7],
#        [3],
#        [15],
#        [3],
#        [20],
#        [3],
#        [20],
# ...

# %%
from sklearn import linear_model as lm
model1=lm.LinearRegression()
results=model1.fit(X_train,y_train)

# %%
accuracy=model1.score(X_train,y_train)

# %%
print("accuracy of model is",accuracy)
# Out:
# accuracy of model is 0.0479058412382779

# %%
X_test.describe()
# Out:
#         Occupation
# count           30
# unique          10
# top              1
# freq            10

# %%
X_test=X_test.values.reshape((30,1))

# %%
predictions=model1.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
X_train=X_train.reshape(69,1)
y_train_prediction=model1.predict(X_train)

# %%
X_test=X_test.reshape(30,1)
y_test_prediction=model1.predict(X_test)

# %%
y_test_prediction=model1.predict(X_test)

# %%
X_train
# Out:
# array([[1],
#        [1],
#        [3],
#        [3],
#        [1],
#        [1],
#        [0],
#        [12],
#        [1],
#        [10],
#        [10],
#        [1],
#        [9],
#        [3],
#        [1],
#        [10],
#        [17],
#        [16],
#        [1],
#        [1],
#        [12],
#        [16],
#        [7],
#        [1],
#        [12],
#        [10],
#        [10],
#        [3],
#        [1],
#        [0],
#        [1],
#        [1],
#        [1],
#        [12],
#        [10],
#        [7],
#        [7],
#        [10],
#        [10],
#        [7],
#        [12],
#        [7],
#        [7],
#        [7],
#        [10],
#        [20],
#        [1],
#        [3],
#        [9],
#        [1],
#        [17],
#        [20],
#        [1],
#        [12],
#        [12],
#        [17],
#        [7],
#        [3],
#        [3],
#        [10],
#        [9],
#        [7],
#        [3],
#        [15],
#        [3],
#        [20],
#        [3],
#        [20],
# ...

# %%
y_train_prediction
# Out:
# array([11505.62220288, 11505.62220288, 11114.08655555, 11114.08655555,
#        11505.62220288, 11505.62220288, 11701.39002654,  9352.17614259,
#        11505.62220288,  9743.71178991,  9743.71178991, 11505.62220288,
#         9939.47961358, 11114.08655555, 11505.62220288,  9743.71178991,
#         8373.33702428,  8569.10484794, 11505.62220288, 11505.62220288,
#         9352.17614259,  8569.10484794, 10331.0152609 , 11505.62220288,
#         9352.17614259,  9743.71178991,  9743.71178991, 11114.08655555,
#        11505.62220288, 11701.39002654, 11505.62220288, 11505.62220288,
#        11505.62220288,  9352.17614259,  9743.71178991, 10331.0152609 ,
#        10331.0152609 ,  9743.71178991,  9743.71178991, 10331.0152609 ,
#         9352.17614259, 10331.0152609 , 10331.0152609 , 10331.0152609 ,
#         9743.71178991,  7786.03355329, 11505.62220288, 11114.08655555,
#         9939.47961358, 11505.62220288,  8373.33702428,  7786.03355329,
# ...

# %%
X_test
# Out:
# array([[10],
#        [3],
#        [1],
#        [3],
#        [3],
#        [9],
#        [1],
#        [3],
#        [10],
#        [10],
#        [1],
#        [1],
#        [1],
#        [3],
#        [7],
#        [1],
#        [7],
#        [1],
#        [10],
#        [20],
#        [10],
#        [1],
#        [7],
#        [0],
#        [12],
#        [1],
#        [10],
#        [17],
#        [1],
#        [15]], dtype=object)

# %%
import numpy as np
rmse_training=(np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training=r2_score(y_train,y_train_prediction)

# %%
print("The model performance for training set")
print("--------------------------------------")
print('RMSE IS []'),format(rmse_training)
print('R2 score is []'),format(r2_training)
# Out:
# The model performance for training set
# --------------------------------------
# RMSE IS []
# R2 score is []
# (None, '0.0479058412382779')

# %%
rmse_testing=(np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing=r2_score(y_test,y_test_prediction)
print("The model performance for testing set")
print("-------------------------------------")
print('Root mean squared error:'),format('rmse_testing')
print('R2_score:'),format ('r2_training')
# Out:
# The model performance for testing set
# -------------------------------------
# Root mean squared error:
# R2_score:
# (None, 'r2_training')

# %%
X=X.values.reshape(99,1)
y_predicted=model1.predict(X)

# %%
plt.plot(X,y_predicted,color='r')
plt.show()

# %% [markdown]
# # Model 2- product category 1

# %%
X=inps[['Product_Category_1']]
y=oups['Purchase']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#    Product_Category_1
# 36                  2
# 52                  8
# 74                  1
# 70                  5
# 39                  1
# 46                  1
# 66                  5
# 23                  8
# 34                  5
# 85                  1
# 96                 11
# 67                  1
# 15                  4
# 82                  5
# 41                  1
# 90                  3
# 26                  8
# 97                  3
# 43                  2
# 53                  1
# 24                  1
# 4                   8
# 56                  1
# 49                  8
# 21                  8
# 86                  1
# 3                  12
# 73                  1
# 30                  5
# 65                  1
# ..                ...
# 57                  8
# 22                  8
# 61                  8
# 63                  8
# 7                   1
# 95                  1
# 13                  1
# 68                  5
# 84                  8
# ...

# %%
y_train
# Out:
# 36    12909
# 52     5839
# 74    19672
# 70     1780
# 39    15705
# 46    11562
# 66     8702
# 23     5982
# 34     5152
# 85     7746
# 96     1539
# 67    15872
# 15     2079
# 82     5430
# 41    18963
# 90    11023
# 26     5887
# 97     3055
# 43    16406
# 53    15912
# 24    11927
# 4      7969
# 56    19653
# 49     8027
# 21     9872
# 86    19525
# 3      1057
# 73    19473
# 30     8886
# 65    11755
#       ...
# 57     5958
# 22     9743
# 61     4209
# 63     7803
# 7     15854
# 95     4211
# 13    15665
# 68     8609
# 84     5912
# 14     5378
# 29    16352
# 28     5391
# 11     3957
# 18    11788
# 20     8584
# 50    15246
# 25    16662
# 6     19215
# 71    10754
# 76    15182
# 1     15200
# 16    13055
# 64    11458
# 79    13551
# 5     15227
# 75    19313
# 9      7871
# 72     2802
# 12     6073
# 37     8770
# Name: Purchase, Length: 69, dtype: int64

# %%
X_train=X_train.values.reshape((69,1))

# %%
X_train
# Out:
# array([[2],
#        [8],
#        [1],
#        [5],
#        [1],
#        [1],
#        [5],
#        [8],
#        [5],
#        [1],
#        [11],
#        [1],
#        [4],
#        [5],
#        [1],
#        [3],
#        [8],
#        [3],
#        [2],
#        [1],
#        [1],
#        [8],
#        [1],
#        [8],
#        [8],
#        [1],
#        [12],
#        [1],
#        [5],
#        [1],
#        [1],
#        [5],
#        [8],
#        [5],
#        [5],
#        [1],
#        [5],
#        [3],
#        [5],
#        [8],
#        [8],
#        [8],
#        [8],
#        [1],
#        [1],
#        [1],
#        [5],
#        [8],
#        [5],
#        [2],
#        [5],
#        [8],
#        [1],
#        [5],
#        [1],
#        [6],
#        [1],
#        [3],
#        [1],
#        [1],
#        [2],
#        [1],
#        [3],
#        [1],
#        [1],
#        [8],
#        [4],
#        [8],
#        [5]], dtype=object)

# %%
from sklearn import linear_model as lm
model2=lm.LinearRegression()
results=model2.fit(X_train,y_train)

# %%
accuracy=model2.score(X_train,y_train)

# %%
print("accuracy of model is",accuracy)
# Out:
# accuracy of model is 0.5130761881826691

# %%
X_test.describe()
# Out:
#         Product_Category_1
# count                   30
# unique                  10
# top                      5
# freq                     8

# %%
X_test=X_test.values.reshape((30,1))

# %%
predictions=model2.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
X_train=X_train.reshape(69,1)
y_train_prediction=model2.predict(X_train)

# %%
X_test=X_test.reshape(30,1)
y_test_prediction=model2.predict(X_test)

# %%
y_test_prediction=model2.predict(X_test)

# %%
X_train
# Out:
# array([[2],
#        [8],
#        [1],
#        [5],
#        [1],
#        [1],
#        [5],
#        [8],
#        [5],
#        [1],
#        [11],
#        [1],
#        [4],
#        [5],
#        [1],
#        [3],
#        [8],
#        [3],
#        [2],
#        [1],
#        [1],
#        [8],
#        [1],
#        [8],
#        [8],
#        [1],
#        [12],
#        [1],
#        [5],
#        [1],
#        [1],
#        [5],
#        [8],
#        [5],
#        [5],
#        [1],
#        [5],
#        [3],
#        [5],
#        [8],
#        [8],
#        [8],
#        [8],
#        [1],
#        [1],
#        [1],
#        [5],
#        [8],
#        [5],
#        [2],
#        [5],
#        [8],
#        [1],
#        [5],
#        [1],
#        [6],
#        [1],
#        [3],
#        [1],
#        [1],
#        [2],
#        [1],
#        [3],
#        [1],
#        [1],
#        [8],
#        [4],
#        [8],
#        [5]], dtype=object)

# %%
y_train_prediction
# Out:
# array([12871.15661803,  5324.77042181, 14128.88765073,  9097.96351992,
#        14128.88765073, 14128.88765073,  9097.96351992,  5324.77042181,
#         9097.96351992, 14128.88765073,  1551.5773237 , 14128.88765073,
#        10355.69455262,  9097.96351992, 14128.88765073, 11613.42558532,
#         5324.77042181, 11613.42558532, 12871.15661803, 14128.88765073,
#        14128.88765073,  5324.77042181, 14128.88765073,  5324.77042181,
#         5324.77042181, 14128.88765073,   293.846291  , 14128.88765073,
#         9097.96351992, 14128.88765073, 14128.88765073,  9097.96351992,
#         5324.77042181,  9097.96351992,  9097.96351992, 14128.88765073,
#         9097.96351992, 11613.42558532,  9097.96351992,  5324.77042181,
#         5324.77042181,  5324.77042181,  5324.77042181, 14128.88765073,
#        14128.88765073, 14128.88765073,  9097.96351992,  5324.77042181,
#         9097.96351992, 12871.15661803,  9097.96351992,  5324.77042181,
# ...

# %%
X_test
# Out:
# array([[11],
#        [8],
#        [5],
#        [4],
#        [2],
#        [5],
#        [5],
#        [5],
#        [1],
#        [11],
#        [8],
#        [3],
#        [1],
#        [2],
#        [5],
#        [8],
#        [1],
#        [1],
#        [1],
#        [5],
#        [12],
#        [6],
#        [5],
#        [8],
#        [1],
#        [1],
#        [3],
#        [5],
#        [14],
#        [1]], dtype=object)

# %%
import numpy as np
rmse_training=(np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training=r2_score(y_train,y_train_prediction)

# %%
print("The model performance for training set")
print("--------------------------------------")
print('RMSE IS []'),format(rmse_training)
print('R2 score is []'),format(r2_training)
# Out:
# The model performance for training set
# --------------------------------------
# RMSE IS []
# R2 score is []
# (None, '0.5130761881826691')

# %%
rmse_testing=(np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing=r2_score(y_test,y_test_prediction)
print("The model performance for testing set")
print("-------------------------------------")
print('Root mean squared error:'),format('rmse_testing')
print('R2_score:'),format ('r2_training')
# Out:
# The model performance for testing set
# -------------------------------------
# Root mean squared error:
# R2_score:
# (None, 'r2_training')

# %%
X=X.values.reshape(99,1)
y_predicted=model2.predict(X)

# %%
plt.plot(X,y_predicted,color='r')
plt.show()

# %% [markdown]
# # Model 3- product category 1, occupation

# %%
X=df1[["Product_Category_1","Occupation"]]
y=df1['Purchase']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#     Product_Category_1  Occupation
# 36                   2           1
# 52                   8           1
# 74                   1           3
# 70                   5           3
# 39                   1           1
# 46                   1           1
# 66                   5           0
# 23                   8          12
# 34                   5           1
# 85                   1          10
# 96                  11          10
# 67                   1           1
# 15                   4           9
# 82                   5           3
# 41                   1           1
# 90                   3          10
# 26                   8          17
# 97                   3          16
# 43                   2           1
# 53                   1           1
# 24                   1          12
# 4                    8          16
# 56                   1           7
# 49                   8           1
# 21                   8          12
# 86                   1          10
# ...

# %%
y_train
# Out:
# 36    12909
# 52     5839
# 74    19672
# 70     1780
# 39    15705
# 46    11562
# 66     8702
# 23     5982
# 34     5152
# 85     7746
# 96     1539
# 67    15872
# 15     2079
# 82     5430
# 41    18963
# 90    11023
# 26     5887
# 97     3055
# 43    16406
# 53    15912
# 24    11927
# 4      7969
# 56    19653
# 49     8027
# 21     9872
# 86    19525
# 3      1057
# 73    19473
# 30     8886
# 65    11755
#       ...
# 57     5958
# 22     9743
# 61     4209
# 63     7803
# 7     15854
# 95     4211
# 13    15665
# 68     8609
# 84     5912
# 14     5378
# 29    16352
# 28     5391
# 11     3957
# 18    11788
# 20     8584
# 50    15246
# 25    16662
# 6     19215
# 71    10754
# 76    15182
# 1     15200
# 16    13055
# 64    11458
# 79    13551
# 5     15227
# 75    19313
# 9      7871
# 72     2802
# 12     6073
# 37     8770
# Name: Purchase, Length: 69, dtype: int64

# %%
X_train=X_train.values.reshape((69,2))

# %%
X_train
# Out:
# array([[ 2,  1],
#        [ 8,  1],
#        [ 1,  3],
#        [ 5,  3],
#        [ 1,  1],
#        [ 1,  1],
#        [ 5,  0],
#        [ 8, 12],
#        [ 5,  1],
#        [ 1, 10],
#        [11, 10],
#        [ 1,  1],
#        [ 4,  9],
#        [ 5,  3],
#        [ 1,  1],
#        [ 3, 10],
#        [ 8, 17],
#        [ 3, 16],
#        [ 2,  1],
#        [ 1,  1],
#        [ 1, 12],
#        [ 8, 16],
#        [ 1,  7],
#        [ 8,  1],
#        [ 8, 12],
#        [ 1, 10],
#        [12, 10],
#        [ 1,  3],
#        [ 5,  1],
#        [ 1,  0],
#        [ 1,  1],
#        [ 5,  1],
#        [ 8,  1],
#        [ 5, 12],
#        [ 5, 10],
#        [ 1,  7],
#        [ 5,  7],
#        [ 3, 10],
#        [ 5, 10],
#        [ 8,  7],
#        [ 8, 12],
#        [ 8,  7],
#        [ 8,  7],
#        [ 1,  7],
#        [ 1, 10],
#        [ 1, 20],
#        [ 5,  1],
#        [ 8,  3],
#        [ 5,  9],
#        [ 2,  1],
#        [ 5, 17],
#        [ 8, 20],
# ...

# %%
from sklearn import linear_model as lm
model3=lm.LinearRegression()
results=model3.fit(X_train,y_train)

# %%
accuracy=model3.score(X_train,y_train)

# %%
print("accuracy of model is",accuracy)
# Out:
# accuracy of model is 0.5133853726739843

# %%
X_test.describe()
# Out:
#        Product_Category_1  Occupation
# count           30.000000   30.000000
# mean             4.933333    5.966667
# std              3.685323    5.486556
# min              1.000000    0.000000
# 25%              1.250000    1.000000
# 50%              5.000000    3.000000
# 75%              7.500000   10.000000
# max             14.000000   20.000000

# %%
X_test=X_test.values.reshape((30,2))

# %%
predictions=model3.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
X_train=X_train.reshape(69,2)
y_train_prediction=model3.predict(X_train)

# %%
X_test=X_test.reshape(30,2)
y_test_prediction=model3.predict(X_test)

# %%
y_test_prediction=model3.predict(X_test)

# %%
X_train
# Out:
# array([[ 2,  1],
#        [ 8,  1],
#        [ 1,  3],
#        [ 5,  3],
#        [ 1,  1],
#        [ 1,  1],
#        [ 5,  0],
#        [ 8, 12],
#        [ 5,  1],
#        [ 1, 10],
#        [11, 10],
#        [ 1,  1],
#        [ 4,  9],
#        [ 5,  3],
#        [ 1,  1],
#        [ 3, 10],
#        [ 8, 17],
#        [ 3, 16],
#        [ 2,  1],
#        [ 1,  1],
#        [ 1, 12],
#        [ 8, 16],
#        [ 1,  7],
#        [ 8,  1],
#        [ 8, 12],
#        [ 1, 10],
#        [12, 10],
#        [ 1,  3],
#        [ 5,  1],
#        [ 1,  0],
#        [ 1,  1],
#        [ 5,  1],
#        [ 8,  1],
#        [ 5, 12],
#        [ 5, 10],
#        [ 1,  7],
#        [ 5,  7],
#        [ 3, 10],
#        [ 5, 10],
#        [ 8,  7],
#        [ 8, 12],
#        [ 8,  7],
#        [ 8,  7],
#        [ 1,  7],
#        [ 1, 10],
#        [ 1, 20],
#        [ 5,  1],
#        [ 8,  3],
#        [ 5,  9],
#        [ 2,  1],
#        [ 5, 17],
#        [ 8, 20],
# ...

# %%
y_train_prediction
# Out:
# array([12954.87471014,  5462.94150041, 14170.74477393,  9176.12263411,
#        14203.5302451 , 14203.5302451 ,  9225.30084086,  5282.621409  ,
#         9208.90810528, 14055.99562485,  1569.4402753 , 14203.5302451 ,
#        10326.42175557,  9176.12263411, 14203.5302451 , 11558.68455494,
#         5200.65773109, 11460.32814144, 12954.87471014, 14203.5302451 ,
#        14023.21015369,  5217.05046667, 14105.1738316 ,  5462.94150041,
#         5282.621409  , 14055.99562485,   320.78474035, 14170.74477393,
#         9208.90810528, 14219.92298068, 14203.5302451 ,  9208.90810528,
#         5462.94150041,  9028.58801387,  9061.37348503, 14105.1738316 ,
#         9110.55169178, 11558.68455494,  9061.37348503,  5364.58508692,
#         5282.621409  ,  5364.58508692,  5364.58508692, 14105.1738316 ,
#        14055.99562485, 13892.06826902,  9208.90810528,  5430.15602925,
#         9077.76622061, 12954.87471014,  8946.62433595,  5151.47952434,
# ...

# %%
X_test
# Out:
# array([[11, 10],
#        [ 8,  3],
#        [ 5,  1],
#        [ 4,  3],
#        [ 2,  3],
#        [ 5,  9],
#        [ 5,  1],
#        [ 5,  3],
#        [ 1, 10],
#        [11, 10],
#        [ 8,  1],
#        [ 3,  1],
#        [ 1,  1],
#        [ 2,  3],
#        [ 5,  7],
#        [ 8,  1],
#        [ 1,  7],
#        [ 1,  1],
#        [ 1, 10],
#        [ 5, 20],
#        [12, 10],
#        [ 6,  1],
#        [ 5,  7],
#        [ 8,  0],
#        [ 1, 12],
#        [ 1,  1],
#        [ 3, 10],
#        [ 5, 17],
#        [14,  1],
#        [ 1, 15]], dtype=int64)

# %%
import numpy as np
rmse_training=(np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training=r2_score(y_train,y_train_prediction)

# %%
print("The model performance for training set")
print("--------------------------------------")
print('RMSE IS []'),format(rmse_training)
print('R2 score is []'),format(r2_training)
# Out:
# The model performance for training set
# --------------------------------------
# RMSE IS []
# R2 score is []
# (None, '0.5133853726739843')

# %%
rmse_testing=(np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing=r2_score(y_test,y_test_prediction)
print("The model performance for testing set")
print("-------------------------------------")
print('Root mean squared error:'),format('rmse_testing')
print('R2_score:'),format ('r2_training')
# Out:
# The model performance for testing set
# -------------------------------------
# Root mean squared error:
# R2_score:
# (None, 'r2_training')

# %%
X=X.values.reshape(99,2)
y_predicted=model3.predict(X)

# %%
plt.plot(X,y_predicted,color='r')
plt.show()
